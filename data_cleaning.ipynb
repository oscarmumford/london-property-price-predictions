# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# Here I am cleaning the two London datasets scraped from Zoopla:
# - The first contains current listings on Zoopla with asking price
# - The second contains ~350,000 historical listings with last sold price.
#
# n.b. The 350k will be extended to contain all available 3.5 million listings in a future scrape

# %% [markdown]
# # GENERAL IMPORTS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import time
from math import ceil

# %% [markdown]
# # CURRENT LISTINGS DATASET

# %%
current_data ="data/csv_data/london_scrape.csv"

# %%
df2 = pd.read_csv(current_data, sep='\t')

# %%
df2.head()
# Out:
#                                           address                price  \
# 0                 Park Street, Chelsea/London SW6           £1,375,000
# 1                      Bridges Court, London SW11             £440,000
# 2                    Carshalton Grove, Sutton SM1  Guide price£650,000
# 3                      Rutland Rd, Forest Gate E7  Guide price£545,000
# 4                      Rutland Rd, Forest Gate E7  Guide price£545,000
# ...                                           ...                  ...
# 9995     Burlington Road, Osterley, Isleworth TW7             £750,000
# 9996        Tufnell Park, Tufnell Park, London N7             £375,000
# 9997  Holmewood Gardens, Brixton Hill, London SW2             £700,000
# 9998                  Coldershaw Road, Ealing W13  Guide price£535,000
# 9999                 Kilravock Street, London W10             £950,000
#
#      bedrooms bathrooms lounges  \
# 0           2         2       1
# 1           1         1       1
# 2           3         2       2
# 3           3         1       2
# 4           3         1       2
# ...       ...       ...     ...
# 9995        3         1       2
# 9996        1         1      na
# 9997        2         1      na
# 9998        2         1       1
# 9999        3         1       2
#
#                                                     url  \
# 0     /new-homes/details/61623573/?search_identifier...
# 1     /for-sale/details/61567435/?search_identifier=...
# 2     /for-sale/details/61623414/?search_identifier=...
# 3     /for-sale/details/61623411/?search_identifier=...
# 4     /for-sale/details/61623405/?search_identifier=...
# ...                                                 ...
# 9995  /for-sale/details/61476741/?search_identifier=...
# 9996  /for-sale/details/61476757/?search_identifier=...
# 9997  /for-sale/details/61476758/?search_identifier=...
# 9998  /for-sale/details/61476750/?search_identifier=...
# 9999  /for-sale/details/61476731/?search_identifier=...
#
#                     nearby_station_1                nearby_station_2
# 0           0.1 miles Imperial Wharf  0.2 miles Chelsea Harbour Pier
# 1     0.4 miles Chelsea Harbour Pier        0.4 miles Imperial Wharf
# 2               0.6 miles Carshalton       0.6 miles Sutton (London)
# 3                 0.4 miles East Ham            0.5 miles Upton Park
# 4                 0.4 miles East Ham            0.5 miles Upton Park
# ...                              ...                             ...
# 9995              0.3 miles Osterley         0.5 miles Hounslow East
# 9996        0.5 miles Upper Holloway          0.5 miles Tufnell Park
# 9997        0.6 miles Streatham Hill            0.8 miles Tulse Hill
# 9998           0.5 miles West Ealing         0.6 miles Drayton Green
# 9999  0.4 miles Queens Park (London)          0.4 miles Queen's Park
#
# [10000 rows x 8 columns]

# %% [markdown]
# ## Nulls

# %%
df2.replace(re.compile('^na$'), np.NaN, inplace=True)

# %%
df2.price
# Out:
# 0                £1,375,000
# 1                  £440,000
# 2       Guide price£650,000
# 3       Guide price£545,000
# 4       Guide price£545,000
#                ...
# 9995               £750,000
# 9996               £375,000
# 9997               £700,000
# 9998    Guide price£535,000
# 9999               £950,000
# Name: price, Length: 10000, dtype: object

# %% [markdown]
# ## Cleaning Price Data

# %%
df2['price_gbp'] = df2[['price']].replace(re.compile(r'[£,\D]'), '').replace(re.compile(r'^$'), np.NaN).astype('float') #.apply(lambda x: np.NaN if x == '' else x) #.astype('float')   #replace(re.compile(r'^$'), None) #.astype('float')

# %%
df2.price_gbp #.replace(re.compile(r'^$'), np.NaN).astype('float')
# Out:
# 0       1375000.0
# 1        440000.0
# 2        650000.0
# 3        545000.0
# 4        545000.0
#           ...
# 9995     750000.0
# 9996     375000.0
# 9997     700000.0
# 9998     535000.0
# 9999     950000.0
# Name: price_gbp, Length: 10000, dtype: float64

# %% [markdown]
# ## Bedrooms, Bathrooms & Lounges 'na' to np.NaN

# %%
for col in ['bedrooms', 'bathrooms', 'lounges']:
    df2[col] = df2[col].replace(np.NaN, None).astype('int')

# %%
df2.drop(columns=['price'], inplace= True)

# %%
(~df2.nearby_station_1.isnull()).sum()
# Out:
# 9856

# %%
df2.nearby_station_1.str.contains('miles').sum()
# Out:
# 9856

# %% [markdown]
# ## Cleaning Nearby Places of Interest

# %%
df2[['distance_to_station_1_miles', 'nearby_station_1']] = df2.nearby_station_1.str.split('miles', expand=True)

# %%
df2[['distance_to_station_2_miles', 'nearby_station_2']] = df2.nearby_station_2.str.split('miles', expand=True)

# %%
df2.address.str.split( r"([Gg][Ii][Rr] 0[Aa]{2})|((([A-Za-z][0-9]{1,2})|(([A-Za-z][A-Ha-hJ-Yj-y][0-9]{1,2})|(([A-Za-z][0-9][A-Za-z])|([A-Za-z][A-Ha-hJ-Yj-y][0-9][A-Za-z]?))))\s?[0-9][A-Za-z]{2})", expand=True)
# Out:
#                                                 0
# 0                 Park Street, Chelsea/London SW6
# 1                      Bridges Court, London SW11
# 2                    Carshalton Grove, Sutton SM1
# 3                      Rutland Rd, Forest Gate E7
# 4                      Rutland Rd, Forest Gate E7
# ...                                           ...
# 9995     Burlington Road, Osterley, Isleworth TW7
# 9996        Tufnell Park, Tufnell Park, London N7
# 9997  Holmewood Gardens, Brixton Hill, London SW2
# 9998                  Coldershaw Road, Ealing W13
# 9999                 Kilravock Street, London W10
#
# [10000 rows x 1 columns]

# %%
df2[['address_no_code', 'postcode_first_half']] = df2.address.str.split(r'([A-Z]{1,2}[0-9]{1,2})', expand=True).iloc[:,[0,1]]

# %%
df2.columns
# Out:
# Index(['address', 'bedrooms', 'bathrooms', 'lounges', 'url',
#        'nearby_station_1', 'nearby_station_2', 'price_gbp',
#        'distance_to_station_1_miles', 'distance_to_station_2_miles',
#        'address_no_code', 'postcode_first_half'],
#       dtype='object')

# %%
reorder = ['address', 'address_no_code' , 'postcode_first_half', 'bedrooms', 'bathrooms', 'lounges', 'url',
       'nearby_station_1', 'distance_to_station_1_miles', 'nearby_station_2', 'distance_to_station_2_miles', 'price_gbp']

# %%
df2 = df2[reorder]

# %%
# !ls data/csv_data_clean/
# Out:
# london_current.csv

# %%
path = 'data/csv_data_clean/london_current.csv'
#df2.to_csv(path, index=False)

# %%
pd.read_csv(path)
# Out:
#                                           address  \
# 0                 Park Street, Chelsea/London SW6
# 1                      Bridges Court, London SW11
# 2                    Carshalton Grove, Sutton SM1
# 3                      Rutland Rd, Forest Gate E7
# 4                      Rutland Rd, Forest Gate E7
# ...                                           ...
# 9995     Burlington Road, Osterley, Isleworth TW7
# 9996        Tufnell Park, Tufnell Park, London N7
# 9997  Holmewood Gardens, Brixton Hill, London SW2
# 9998                  Coldershaw Road, Ealing W13
# 9999                 Kilravock Street, London W10
#
#                                address_no_code postcode_first_half  bedrooms  \
# 0                 Park Street, Chelsea/London                  SW6         2
# 1                       Bridges Court, London                 SW11         1
# 2                    Carshalton Grove, Sutton                  SM1         3
# 3                     Rutland Rd, Forest Gate                   E7         3
# 4                     Rutland Rd, Forest Gate                   E7         3
# ...                                        ...                 ...       ...
# 9995     Burlington Road, Osterley, Isleworth                  TW7         3
# 9996       Tufnell Park, Tufnell Park, London                   N7         1
# 9997  Holmewood Gardens, Brixton Hill, London                  SW2         2
# 9998                  Coldershaw Road, Ealing                  W13         2
# 9999                 Kilravock Street, London                  W10         3
#
#       bathrooms  lounges                                                url  \
# 0             2        1  /new-homes/details/61623573/?search_identifier...
# 1             1        1  /for-sale/details/61567435/?search_identifier=...
# 2             2        2  /for-sale/details/61623414/?search_identifier=...
# 3             1        2  /for-sale/details/61623411/?search_identifier=...
# 4             1        2  /for-sale/details/61623405/?search_identifier=...
# ...         ...      ...                                                ...
# 9995          1        2  /for-sale/details/61476741/?search_identifier=...
# 9996          1        2  /for-sale/details/61476757/?search_identifier=...
# 9997          1        2  /for-sale/details/61476758/?search_identifier=...
# 9998          1        1  /for-sale/details/61476750/?search_identifier=...
# 9999          1        2  /for-sale/details/61476731/?search_identifier=...
#
#            nearby_station_1  distance_to_station_1_miles  \
# 0            Imperial Wharf                          0.1
# 1      Chelsea Harbour Pier                          0.4
# 2                Carshalton                          0.6
# 3                  East Ham                          0.4
# 4                  East Ham                          0.4
# ...                     ...                          ...
# 9995               Osterley                          0.3
# 9996         Upper Holloway                          0.5
# 9997         Streatham Hill                          0.6
# 9998            West Ealing                          0.5
# 9999   Queens Park (London)                          0.4
#
#            nearby_station_2  distance_to_station_2_miles  price_gbp
# 0      Chelsea Harbour Pier                          0.2  1375000.0
# 1            Imperial Wharf                          0.4   440000.0
# 2           Sutton (London)                          0.6   650000.0
# 3                Upton Park                          0.5   545000.0
# 4                Upton Park                          0.5   545000.0
# ...                     ...                          ...        ...
# 9995          Hounslow East                          0.5   750000.0
# 9996           Tufnell Park                          0.5   375000.0
# 9997             Tulse Hill                          0.8   700000.0
# 9998          Drayton Green                          0.6   535000.0
# 9999           Queen's Park                          0.4   950000.0
#
# [10000 rows x 12 columns]

# %%
df2.iloc[:,1]
# Out:
# 0                   Park Street, Chelsea/London
# 1                         Bridges Court, London
# 2                      Carshalton Grove, Sutton
# 3                       Rutland Rd, Forest Gate
# 4                       Rutland Rd, Forest Gate
#                           ...
# 9995       Burlington Road, Osterley, Isleworth
# 9996         Tufnell Park, Tufnell Park, London
# 9997    Holmewood Gardens, Brixton Hill, London
# 9998                    Coldershaw Road, Ealing
# 9999                   Kilravock Street, London
# Name: address_no_code, Length: 10000, dtype: object

# %% [markdown]
# # HISTORICAL PRICE DATASET

# %%
data ="data/csv_data/london_historical_scrape.csv"

# %%
df =pd.read_csv(data, sep='\t')

# %% [markdown]
# ## Splitting Address To Get Postcode

# %%
df[df.address.str.contains(r"24 Oaklands Avenue, Sidcup, DA15 8NB")]
# Out:
#                                      address last_sold_date last_sold_price  \
# 308203  24 Oaklands Avenue, Sidcup, DA15 8NB     Last sold                -
#
#             estimated_price  bedrooms  bathrooms  lounges  \
# 308203  £435,000 - £532,000       NaN        NaN      NaN
#
#                                  url    tenure        property_type
# 308203  /property/uprn/100020257388/  freehold  semi-detached house

# %%
df
# Out:
#                                        address         last_sold_date  \
# 0         1 Bickley Crescent, Bromley, BR1 2DN  Last sold  - Oct 1999
# 1              1 Chadd Drive, Bromley, BR1 2DP  Last sold  - Jul 2018
# 2          1 Page Heath Lane, Bromley, BR1 2DR  Last sold  - Jan 2007
# 3          1 Beresford Drive, Bromley, BR1 2DU  Last sold  - Nov 2006
# 4       1 St Michael's Close, Bromley, BR1 2DX  Last sold  - Nov 2006
# ...                                        ...                    ...
# 308341  25 Orchard Rise East, Sidcup, DA15 8RU  Last sold  - Aug 2005
# 308342       25 Chester Road, Sidcup, DA15 8RX  Last sold  - May 2018
# 308343      25 Ridgeway East, Sidcup, DA15 8RY             Last sold
# 308344      25 Ridgeway West, Sidcup, DA15 8SF             Last sold
# 308345      25 Boundary Road, Sidcup, DA15 8SS             Last sold
#
#        last_sold_price      estimated_price  bedrooms  bathrooms  lounges  \
# 0              £97,500  £461,000 - £564,000       2.0        NaN      2.0
# 1             £675,000  £789,000 - £872,000       NaN        NaN      NaN
# 2             £480,000  £740,000 - £905,000       4.0        2.0      2.0
# 3             £420,000  £830,000 - £918,000       3.0        1.0      3.0
# 4             £376,000  £740,000 - £904,000       NaN        NaN      NaN
# ...                ...                  ...       ...        ...      ...
# 308341        £180,000  £411,000 - £454,000       3.0        NaN      2.0
# 308342        £323,000  £386,000 - £426,000       3.0        1.0      1.0
# 308343               -  £402,000 - £445,000       NaN        NaN      NaN
# 308344               -  £394,000 - £482,000       NaN        NaN      NaN
# 308345               -  £537,000 - £656,000       NaN        NaN      NaN
#
#                                  url    tenure        property_type
# 0       /property/uprn/100020390465/  freehold  semi-detached house
# 1       /property/uprn/100020393770/  freehold       detached house
# 2       /property/uprn/100020408794/  freehold  semi-detached house
# 3       /property/uprn/100020390386/  freehold       detached house
# 4       /property/uprn/100020416127/  freehold       detached house
# ...                              ...       ...                  ...
# 308341  /property/uprn/100020257952/  freehold    mid terrace house
# 308342  /property/uprn/100020247967/  freehold     terrace property
# 308343  /property/uprn/100020259734/  freehold     terrace property
# 308344  /property/uprn/100020259766/  freehold     terrace property
# 308345  /property/uprn/100020246523/       NaN  semi-detached house
#
# [308346 rows x 10 columns]

# %%
df[['unprocessed_address', 'postcode']] = df.address.str.split( r"([Gg][Ii][Rr] 0[Aa]{2})|((([A-Za-z][0-9]{1,2})|(([A-Za-z][A-Ha-hJ-Yj-y][0-9]{1,2})|(([A-Za-z][0-9][A-Za-z])|([A-Za-z][A-Ha-hJ-Yj-y][0-9][A-Za-z]?))))\s?[0-9][A-Za-z]{2})", expand=True).loc[:,[0,2]]

# %%
df[['paon', 'address_processing_2']] = df.unprocessed_address.str.split(",", n=1, expand=True).iloc[:]

# %%
#df.address_processing_2.str.split("[0-9]+[],", expand=True, n=1).loc[:,1].value_counts()

# %%
df.address_processing_2.str.split("([a-zA-Z -,]*[0-9]+[a-zA-Z -]*,)", expand=True).loc[:,1].value_counts()
# Out:
#  Pinnacle Apartments, 11 Saffron Central Square,    240
#  Tennyson Apartments, 1 Saffron Central Square,     207
#  Bertha James Court, 32 Masons Hill,                204
#  1 Newgate,                                         183
#  Rosing Apartments, 45 Homesdale Road,              164
#                                                    ...
#  13 Bywood Avenue,                                    1
#  13 Farquharson Road,                                 1
#  13 Duppas Hill Road,                                 1
#  13 Witherby Close,                                   1
#  16 Christchurch Road,                                1
# Name: 1, Length: 4918, dtype: int64

# %% [markdown]
# ## Cleaning and Splitting Scraped Last Sold Date (Month-Year)

# %%
df[['month_sold_last', 'year_sold_last']] = df.last_sold_date.str.split("Last sold[ -]*([A-Za-z]{3}) ([0-9]{4})", expand=True).loc[:,[1,2]]

# %% [markdown]
# ## Cleaning Price Data (Last Sold & Zoopla Estimates)

# %%
df["last_sold_price_gbp"] = df.last_sold_price.str.replace("£","").str.replace(",","").replace("-", "").replace(re.compile(r"^$"), np.NaN).astype("float")

# %%
df[['min_estimate_gbp','max_estimate_gbp']] = df.estimated_price.str.split(r"£([0-9,.]+) - £([0-9,.]+)", expand=True).iloc[:,[1,2]]

# %%
df.min_estimate_gbp = df.min_estimate_gbp.str.replace("£","").str.replace(",","").astype("float")

# %%
df.max_estimate_gbp = df.max_estimate_gbp.str.replace("£","").str.replace(",","").astype("float")

# %% [markdown]
# ## Cleaning Scraped Bedroom, Bathroom & Lounge Counts

# %%
for col in ['bedrooms', 'bathrooms', 'lounges']:
    df[col] = df[col].replace(np.NaN, None) #.astype('int')

# %%
df.bathrooms.replace(np.NaN, None)
# Out:
# 0         NaN
# 1         NaN
# 2         2.0
# 3         1.0
# 4         1.0
#          ...
# 308341    1.0
# 308342    1.0
# 308343    1.0
# 308344    1.0
# 308345    1.0
# Name: bathrooms, Length: 308346, dtype: float64

# %%
df['lounges'] = df.lounges.replace(np.NaN, None).astype('int')

# %%
df.drop(columns=['last_sold_date','last_sold_price','estimated_price'], inplace=True )

# %%
col_reorder = ['address', 'unprocessed_address',  'paon',
       'saon', 'postcode', 'bedrooms', 'bathrooms', 'lounges', 'url', 'tenure',
       'property_type', 'month_sold_last', 'year_sold_last',
       'last_sold_price_gbp', 'min_estimate_gbp', 'max_estimate_gbp']

# %%
df.rename(columns={'address_processing_2':'saon'}, inplace=True)

# %%
df = df[col_reorder]

# %%
df['saon'] = df.saon.str.replace(re.compile(r", *$"), "")

# %%
outfile = 'data/csv_data_clean/london_historical.csv'

# %%
df.to_csv(outfile, index=False)

# %%
pd.read_csv(outfile)
# Out:
#                                        address  \
# 0         1 Bickley Crescent, Bromley, BR1 2DN
# 1              1 Chadd Drive, Bromley, BR1 2DP
# 2          1 Page Heath Lane, Bromley, BR1 2DR
# 3          1 Beresford Drive, Bromley, BR1 2DU
# 4       1 St Michael's Close, Bromley, BR1 2DX
# ...                                        ...
# 308341  25 Orchard Rise East, Sidcup, DA15 8RU
# 308342       25 Chester Road, Sidcup, DA15 8RX
# 308343      25 Ridgeway East, Sidcup, DA15 8RY
# 308344      25 Ridgeway West, Sidcup, DA15 8SF
# 308345      25 Boundary Road, Sidcup, DA15 8SS
#
#                     unprocessed_address                  paon      saon  \
# 0         1 Bickley Crescent, Bromley,     1 Bickley Crescent   Bromley
# 1              1 Chadd Drive, Bromley,          1 Chadd Drive   Bromley
# 2          1 Page Heath Lane, Bromley,      1 Page Heath Lane   Bromley
# 3          1 Beresford Drive, Bromley,      1 Beresford Drive   Bromley
# 4       1 St Michael's Close, Bromley,   1 St Michael's Close   Bromley
# ...                                 ...                   ...       ...
# 308341   25 Orchard Rise East, Sidcup,   25 Orchard Rise East    Sidcup
# 308342        25 Chester Road, Sidcup,        25 Chester Road    Sidcup
# 308343       25 Ridgeway East, Sidcup,       25 Ridgeway East    Sidcup
# 308344       25 Ridgeway West, Sidcup,       25 Ridgeway West    Sidcup
# 308345       25 Boundary Road, Sidcup,       25 Boundary Road    Sidcup
#
#         postcode  bedrooms  bathrooms  lounges                           url  \
# 0        BR1 2DN       2.0        NaN        2  /property/uprn/100020390465/
# 1        BR1 2DP       2.0        NaN        2  /property/uprn/100020393770/
# 2        BR1 2DR       4.0        2.0        2  /property/uprn/100020408794/
# 3        BR1 2DU       3.0        1.0        3  /property/uprn/100020390386/
# 4        BR1 2DX       3.0        1.0        3  /property/uprn/100020416127/
# ...          ...       ...        ...      ...                           ...
# 308341  DA15 8RU       3.0        1.0        2  /property/uprn/100020257952/
# 308342  DA15 8RX       3.0        1.0        1  /property/uprn/100020247967/
# 308343  DA15 8RY       3.0        1.0        1  /property/uprn/100020259734/
# 308344  DA15 8SF       3.0        1.0        1  /property/uprn/100020259766/
# 308345  DA15 8SS       3.0        1.0        1  /property/uprn/100020246523/
#
#           tenure        property_type month_sold_last  year_sold_last  \
# 0       freehold  semi-detached house             Oct          1999.0
# 1       freehold       detached house             Jul          2018.0
# 2       freehold  semi-detached house             Jan          2007.0
# 3       freehold       detached house             Nov          2006.0
# 4       freehold       detached house             Nov          2006.0
# ...          ...                  ...             ...             ...
# 308341  freehold    mid terrace house             Aug          2005.0
# 308342  freehold     terrace property             May          2018.0
# 308343  freehold     terrace property             NaN             NaN
# 308344  freehold     terrace property             NaN             NaN
# 308345       NaN  semi-detached house             NaN             NaN
#
#         last_sold_price_gbp  min_estimate_gbp  max_estimate_gbp
# 0                   97500.0          461000.0          564000.0
# 1                  675000.0          789000.0          872000.0
# 2                  480000.0          740000.0          905000.0
# 3                  420000.0          830000.0          918000.0
# 4                  376000.0          740000.0          904000.0
# ...                     ...               ...               ...
# 308341             180000.0          411000.0          454000.0
# 308342             323000.0          386000.0          426000.0
# 308343                  NaN          402000.0          445000.0
# 308344                  NaN          394000.0          482000.0
# 308345                  NaN          537000.0          656000.0
#
# [308346 rows x 16 columns]

# %% [markdown]
# # CLEANING (FROM EDA NOTEBOOK)

# %% [markdown]
# ## IMPORT DATASETS

# %%
hist_data = 'data/csv_data_clean/london_historical.csv' 
curr_data = 'data/csv_data_clean/london_current.csv'

# %%
hist_df = pd.read_csv(hist_data)

# %%
hist_df
# Out:
#                                        address  \
# 0         1 Bickley Crescent, Bromley, BR1 2DN
# 1              1 Chadd Drive, Bromley, BR1 2DP
# 2          1 Page Heath Lane, Bromley, BR1 2DR
# 3          1 Beresford Drive, Bromley, BR1 2DU
# 4       1 St Michael's Close, Bromley, BR1 2DX
# ...                                        ...
# 308341  25 Orchard Rise East, Sidcup, DA15 8RU
# 308342       25 Chester Road, Sidcup, DA15 8RX
# 308343      25 Ridgeway East, Sidcup, DA15 8RY
# 308344      25 Ridgeway West, Sidcup, DA15 8SF
# 308345      25 Boundary Road, Sidcup, DA15 8SS
#
#                     unprocessed_address                  paon      saon  \
# 0         1 Bickley Crescent, Bromley,     1 Bickley Crescent   Bromley
# 1              1 Chadd Drive, Bromley,          1 Chadd Drive   Bromley
# 2          1 Page Heath Lane, Bromley,      1 Page Heath Lane   Bromley
# 3          1 Beresford Drive, Bromley,      1 Beresford Drive   Bromley
# 4       1 St Michael's Close, Bromley,   1 St Michael's Close   Bromley
# ...                                 ...                   ...       ...
# 308341   25 Orchard Rise East, Sidcup,   25 Orchard Rise East    Sidcup
# 308342        25 Chester Road, Sidcup,        25 Chester Road    Sidcup
# 308343       25 Ridgeway East, Sidcup,       25 Ridgeway East    Sidcup
# 308344       25 Ridgeway West, Sidcup,       25 Ridgeway West    Sidcup
# 308345       25 Boundary Road, Sidcup,       25 Boundary Road    Sidcup
#
#         postcode  bedrooms  bathrooms  lounges                           url  \
# 0        BR1 2DN       2.0        NaN        2  /property/uprn/100020390465/
# 1        BR1 2DP       2.0        NaN        2  /property/uprn/100020393770/
# 2        BR1 2DR       4.0        2.0        2  /property/uprn/100020408794/
# 3        BR1 2DU       3.0        1.0        3  /property/uprn/100020390386/
# 4        BR1 2DX       3.0        1.0        3  /property/uprn/100020416127/
# ...          ...       ...        ...      ...                           ...
# 308341  DA15 8RU       3.0        1.0        2  /property/uprn/100020257952/
# 308342  DA15 8RX       3.0        1.0        1  /property/uprn/100020247967/
# 308343  DA15 8RY       3.0        1.0        1  /property/uprn/100020259734/
# 308344  DA15 8SF       3.0        1.0        1  /property/uprn/100020259766/
# 308345  DA15 8SS       3.0        1.0        1  /property/uprn/100020246523/
#
#           tenure        property_type month_sold_last  year_sold_last  \
# 0       freehold  semi-detached house             Oct          1999.0
# 1       freehold       detached house             Jul          2018.0
# 2       freehold  semi-detached house             Jan          2007.0
# 3       freehold       detached house             Nov          2006.0
# 4       freehold       detached house             Nov          2006.0
# ...          ...                  ...             ...             ...
# 308341  freehold    mid terrace house             Aug          2005.0
# 308342  freehold     terrace property             May          2018.0
# 308343  freehold     terrace property             NaN             NaN
# 308344  freehold     terrace property             NaN             NaN
# 308345       NaN  semi-detached house             NaN             NaN
#
#         last_sold_price_gbp  min_estimate_gbp  max_estimate_gbp
# 0                   97500.0          461000.0          564000.0
# 1                  675000.0          789000.0          872000.0
# 2                  480000.0          740000.0          905000.0
# 3                  420000.0          830000.0          918000.0
# 4                  376000.0          740000.0          904000.0
# ...                     ...               ...               ...
# 308341             180000.0          411000.0          454000.0
# 308342             323000.0          386000.0          426000.0
# 308343                  NaN          402000.0          445000.0
# 308344                  NaN          394000.0          482000.0
# 308345                  NaN          537000.0          656000.0
#
# [308346 rows x 16 columns]
